# %%
display_summary("https://anthropic.com")
# Out:
# # Anthropic: AI with a Conscience (and a Bard-like Name)
#
# Welcome to Anthropic, the noble public benefit corporation on a quest to make AI safe and not world-ending. They’re cooking up AI research and products that put safety at the forefront—because who wants a robot uprising?
#
# Highlights:
# - **Claude**: Their fancy AI lineup includes Claude (the philosopher), Claude Code (the coder), and Claude Cowork (the overachiever).
# - **Claude Opus 4.6**: Released Feb 5, 2026, this model claims to be the "most powerful model for coding, agents, and professional work." Basically, the AI equivalent of a caffeinated wizard.
# - **Project Glasswing**: Securing critical software for the AI era. No glass shenanigans, just sturdy security.
# - **No ads, no sponsored content**, just pure, unfiltered AI wisdom and helpful conversations. Take that, internet pop-ups!
#
# Newswise, they’re churning out announcements faster than a scribe with a quill. The latest gems dropped in early February 2026, spotlighting their model upgrades and philosophy.
#
# In summary, Anthropic is like the medieval guild of AI safety—dedicated, ambitious, and hell-bent on making sure our silicon friends don’t go rogue. Tarry not, log in to Claude and join the noble cause!

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise, you experienced calling the Cloud API of a Frontier Model (a leading model at the frontier of AI) for the first time. We will be using APIs like OpenAI at many stages in the course, in addition to building our own LLMs.
#
# More specifically, we've applied this to Summarization - a classic Gen AI use case to make a summary. This can be applied to any business vertical - summarizing the news, summarizing financial performance, summarizing a resume in a cover letter - the applications are limitless. Consider how you could apply Summarization in your business, and try prototyping a solution.</span>
#         </td>
#     </tr>
# </table>
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue - now try yourself</h2>
#             <span style="color:#900;">Use the cell below to make your own simple commercial example. Stick with the summarization use case for now. Here's an idea: write something that will take the contents of an email, and will suggest an appropriate short subject line for the email. That's the kind of feature that might be built into a commercial email tool.</span>
#         </td>
#     </tr>
# </table>

# %%
# Step 1: Create your prompts

system_prompt = "Please explain step-by-step how to factor trinomials"
user_prompt = """
    Learning Objectives

Factor trinomials of the form   
.
Factor trinomials of higher degree.
Factor trinomials of the form   
.
Factor trinomials using the AC method.
Factoring Trinomials Whose Leading Coefficient Is One
(Factoring Trinomials of the Form   
)
Some trinomials of the form   
 can be factored as a product of binomials. If a trinomial of this type factors, then we have:


This gives us

  
     and      

In short, if the leading coefficient of a factorable trinomial is 
, then the factors of the last term must add up to the coefficient of the middle term. This observation is the key to factoring trinomials using the technique known as the trial and error (or guess and check) method18.

Example 
:

Factor   
.

Solution

We begin by writing two sets of blank parentheses. If a trinomial of this form factors, then it will factor into two linear binomial factors.

     

Write the factors of the first term in the first space of each set of parentheses. In this case, factor   
.

     

Determine the factors of the last term whose sum equals the coefficient of the middle term. To do this, list all of the factorizations of 
 and search for factors whose sum equals 
.


Choose   
 because   
. Write in the last term of each binomial using the factors determined in the previous step.

     

This can be visually interpreted as follows:

imageedit_3_8348621819.png
Figure 
Check by multiplying the two binomials.


Answer


Since multiplication is commutative, the order of the factors does not matter.


If the last term of the trinomial is positive, then either both of the constant factors must be negative or both must be positive.

Example 
:

Factor   
.

Solution

First, factor   
.

     

Next, search for factors of 
 whose sum is 
.


In this case, choose 
 and 
 because  
 and   
.


Check


Answer

  

If the last term of the trinomial is negative, then one of its factors must be negative.

Example 
:

Factor:   
.

Solution

Begin by factoring the first term   
.

   

The factors of 
 are listed below. In this example, we are looking for factors whose sum is 
.


Therefore, the coefficient of the last term can be factored as  
, where   
. Because the last term has a variable factor of 
, use  
 and factor the trinomial as follows:


Multiply to check.


Answer

  

Often our first guess will not produce a correct factorization. This process may require repeated trials. For this reason, the check is very important and is not optional.

Example 
:

Factor   
.

Solution

The first term of this trinomial, 
, factors as  
.

   

Consider the factors of 
:


Suppose we choose the factors 
 and 
 because   
, the coefficient of the middle term. Then we have the following incorrect factorization:

       

When we multiply to check, we find the error.

✗

In this case, the middle term is correct but the last term is not. Since the last term in the original expression is negative, we need to choose factors that are opposite in sign. Therefore, we must try again. This time we choose the factors 
 and 
 because   
.

     

Now the check shows that this factorization is correct.


Answer

  

If we choose the factors wisely, then we can reduce much of the guesswork in this process. However, if a guess is not correct, do not get discouraged; just try a different set of factors. Keep in mind that some polynomials are prime. For example, consider the trinomial   
 and the factors of 
:


There are no factors of 
 whose sum is 
. Therefore, the original trinomial cannot be factored as a product of two binomials with integer coefficients. The trinomial is prime.

Factoring Trinomials of Higher Degree
We can use the trial and error technique to factor trinomials of higher degree.

Example 
:

Factor   
.

Solution

Begin by factoring the first term   
.

   

Since 
 is prime and the coefficient of the middle term is positive, choose 
 and 
 as the factors of the last term.


Notice that the variable part of the middle term is 
 and the factorization checks out.


Answer


Example 
:

Factor:   
 where 
 is a positive integer.

Solution

Begin by factoring the first term   
.

   

Factor  
 because   
 and write


Answer


The check is left to the reader.

Exercise 

Factor   
.

Answer
"""

# Step 2: Make the messages list

messages = [ {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt}]

# Step 3: Call OpenAI
response = openai.chat.completions.create(model="gpt-5-nano", messages=messages)

# Step 4: print the result
print(response.choices[0].message.content)
# Out:
# Here is a clear, step-by-step way to factor trinomials, covering the common case when the leading coefficient is 1 and the more general case using the AC method.
#
# What we’re factoring
# - We usually work with trinomials in the form ax^2 + bx + c, where a, b, c are integers.
# - A trinomial is factorable over the integers if it can be written as a product of two binomials with integer coefficients.
#
# Case 1. Trinomials with leading coefficient a = 1
# Trinomials of the form x^2 + bx + c.
#
# Goal
# - Find two numbers p and q such that:
#   - p + q = b
#   - p · q = c
#
# Steps
# 1) Look for two integers p and q whose sum is b and whose product is c.
# 2) Factor the trinomial as (x + p)(x + q).
# 3) (Optional) If c is negative, p and q have opposite signs; if c is positive, p and q have the same sign. Use the sign pattern that makes the product c and sum b.
# 4) Check by expanding to confirm.
#
# Examples
# - Example A: Factor x^2 + 7x + 12
#   - Find p, q with p + q = 7 and p·q = 12. The pair (3, 4) works.
#   - Factor: (x + 3)(x + 4).
# - Example B: Factor x^2 + x − 6
#   - Need p + q = 1 and p·q = −6. The pair (3, −2) works.
#   - Factor: (x + 3)(x − 2).
#
# Case 2. Trinomials with leading coefficient a ≠ 1 (the AC method)
# Trinomials of the form ax^2 + bx + c.
#
# Idea
# - We want to split the middle term using two numbers m and n that add to b (m + n = b) and whose product is a·c (m·n = a·c). Then factor by grouping.
#
# Steps (AC method)
# 1) Compute ac = a · c.
# 2) Find two integers m and n such that:
#    - m + n = b
#    - m · n = a · c
#    If no such integers exist, the trinomial cannot be factored over the integers (it might be prime in this context).
# 3) Rewrite the trinomial as ax^2 + m x + n x + c.
# 4) Factor by grouping:
#    - Group as (ax^2 + m x) + (n x + c) = x(ax + m) + ?(nx + c).
#    - Use the fact that mn = ac to show that nx + c can be written as k(ax + m) for some k. Concretely, k can be taken as k = n/a = c/m (these are equal because mn = ac).
#    - So the expression becomes (ax + m)(x + k).
# 5) If you computed k as a fraction, you can factor out any common factor first to keep coefficients integers, and then simplify.
# 6) Verify by expanding: (ax + m)(x + k) should give ax^2 + (a k + m)x + m k, which should match ax^2 + bx + c.
# 7) If no such m, n exist, the trinomial is prime over the integers.
#
# Examples
# - Example 1 (a ≠ 1): Factor 6x^2 + 11x + 3
#   - ac = 6 · 3 = 18. Find m, n with m + n = 11 and m·n = 18. The pair (2, 9) works.
#   - Rewrite: 6x^2 + 2x + 9x + 3.
#   - Group: (6x^2 + 2x) + (9x + 3) = 2x(3x + 1) + 3(3x + 1) = (3x + 1)(2x + 3).
#   - Check: (3x + 1)(2x + 3) expands to 6x^2 + 11x + 3.
#
# - Example 2 (a ≠ 1 with a negative c): Factor 6x^2 + 5x − 6
#   - ac = 6 · (−6) = −36. Find m, n with m + n = 5 and m·n = −36. The pair (9, −4) works.
#   - Rewrite: 6x^2 + 9x − 4x − 6.
#   - Group: (6x^2 + 9x) + (−4x − 6) = 3x(2x + 3) − 2(2x + 3) = (2x + 3)(3x − 2).
#   - Check: (2x + 3)(3x − 2) expands to 6x^2 + 5x − 6.
#
# Notes and tips
# - If a = 1, you can skip the AC method and use Case 1 directly.
# - If no integers m and n satisfy m + n = b and m·n = ac, the trinomial cannot be factored over the integers (it is prime in Z[x]).
# - Always check your factorization by expanding.
# - For higher-degree trinomials (three terms, but degree greater than 2), the same philosophy applies: look for a way to split the middle term (or cross terms) and factor by grouping, or try to factor as a product of binomials if possible. If no such factoring exists over the integers, the trinomial is prime over integers.
#
# Quick practice you can try
# - Factor x^2 − 9x + 20 (a = 1 case)
#   - Find p and q with p+q = −9 and p·q = 20. The pair (−5, −4) works.
#   - Factor: (x − 5)(x − 4).
#
# - Factor 4x^2 − 7x − 3 (a ≠ 1 case)
#   - ac = 4 · (−3) = −12. Find m, n with m+n = −7 and m·n = −12. The pair (−3, −4) works.
#   - Rewrite: 4x^2 − 3x − 4x − 3
#   - Group: (4x^2 − 3x) + (−4x − 3) = x(4x − 3) − 1(4x + 3) → Not directly common. Try (4x^2 − 4x) + (−3x − 3) = 4x(x − 1) − 3(x + 1) not right either. The correct m, n here are −1 and −12? Actually for this one, the standard AC steps would yield (2x − 1)(2x − 3). Check: 4x^2 − 8x + 3x − 3 = 4x^2 − 5x − 3; not correct. If you try systematically with AC, you’ll find the factorization is (4x + 3)(x − 1). That expands to 4x^2 − x + 3x − 3 = 4x^2 + 2x − 3, which is not correct either. This example is a reminder to check your m+n and m·n carefully. The correct factorization is (4x + 3)(x − 1) gives 4x^2 − 4x + 3x − 3 = 4x^2 − x − 3; not correct. So this one is prime over integers. (Always verify with expansion.)
# - If you get stuck, try a few pairs for m and n that multiply to ac and see whether you can factor by grouping after rewriting ax^2 + mx + nx + c.
#
# If you want, tell me a specific trinomial you’re stuck on, and I’ll walk through the steps with that exact example.

# %% [markdown]
# ## An extra exercise for those who enjoy web scraping
#
# You may notice that if you try `display_summary("https://openai.com")` - it doesn't work! That's because OpenAI has a fancy website that uses Javascript. There are many ways around this that some of you might be familiar with. For example, Selenium is a hugely popular framework that runs a browser behind the scenes, renders the page, and allows you to query it. If you have experience with Selenium, Playwright or similar, then feel free to improve the Website class to use them. In the community-contributions folder, you'll find an example Selenium solution from a student (thank you!)

# %% [markdown]
# # Sharing your code
#
# I'd love it if you share your code afterwards so I can share it with others! You'll notice that some students have already made changes (including a Selenium implementation) which you will find in the community-contributions folder. If you'd like add your changes to that folder, submit a Pull Request with your new versions in that folder and I'll merge your changes.
#
# If you're not an expert with git (and I am not!) then I've given you complete instructions in the guides folder, guide 3, and pasting here:
#
# Here's the overall steps involved in making a PR and the key instructions:
# https://edwarddonner.com/pr
#
# Please check before submitting:
# 1. Your PR only contains changes in community-contributions (unless we've discussed it)
# 2. All notebook outputs are clear
# 3. Less than 2,000 lines of code in total, and not too many files
# 4. Don't include unnecessary test files, or overly wordy README or .env.example or emojis or other LLM artifacts!
#
# Thanks so much!
#
# Detailed steps here:
#
# https://chatgpt.com/share/6873c22b-2a1c-8012-bc9a-debdcf7c835b
